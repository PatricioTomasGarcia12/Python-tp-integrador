# %%
import ej02_funciones
import csv

ruta = "Colección Ornitológica del IADIZA-CCT CONICET Mendoza IADIZA-COI/occurrence.txt"
delimiter = "\t"

j02_funciones.imprimir_1ras_10filas(ruta, delimiter)
print(f"-------------------"*20)
ej02_funciones.imprimir_columnas(ruta, delimiter)
print(f"-------------------"*20)
ej02_funciones.retornar_indice_columna(ruta, delimiter)
print(f"-------------------"*20)
print(ej02_funciones.cant_total_registros(ruta, delimiter))
print(f"-------------------"*20)
print(ej02_funciones.columnas_vacias(ruta, delimiter))
print(f"-------------------"*20)
porcentaje = ej02_funciones.porcentaje_columnas_nulas(ruta, delimiter)
for keys, values in porcentaje.items():
    print(f"{keys} : {values} %")
print(f"-------------------"*20)
nombre = input("Escriba el nombre de una columna: ")
res = ej02_funciones.dado_nombre_columna(ruta,nombre, delimiter)
if res != None:
    print(f"La cantidad de valores distintos de {nombre} es: {res}")
print(f"-------------------"*20)
nombre_columna = input("Escriba el nombre de una columna: ")
res_columna = ej02_funciones.frecuencia_columna(ruta,nombre_columna, delimiter)
for keys, values in res_columna.items():
    print(f"{keys} : {values}")
# Out:
# {'gbifID': '1660908055', 'accessRights': '', 'bibliographicCitation': '', 'language': '', 'license': 'CC_BY_NC_4_0', 'modified': '2015-05-19T00:00:00Z', 'publisher': '', 'references': '', 'rightsHolder': '', 'type': '', 'institutionID': '', 'collectionID': '', 'datasetID': '', 'institutionCode': 'IADIZA', 'collectionCode': 'COI', 'datasetName': '', 'ownerInstitutionCode': '', 'basisOfRecord': 'PRESERVED_SPECIMEN', 'informationWithheld': '', 'dataGeneralizations': '', 'dynamicProperties': '', 'occurrenceID': 'IADIZA:COI:006861', 'catalogNumber': '006861', 'recordNumber': '', 'recordedBy': 'R.G. Spurr', 'recordedByID': '', 'individualCount': '', 'organismQuantity': '', 'organismQuantityType': '', 'sex': '', 'lifeStage': '', 'reproductiveCondition': '', 'caste': '', 'behavior': '', 'vitality': '', 'establishmentMeans': '', 'degreeOfEstablishment': '', 'pathway': '', 'georeferenceVerificationStatus': '', 'occurrenceStatus': 'PRESENT', 'preparations': '', 'disposition': '', 'associatedOcc
# ...
