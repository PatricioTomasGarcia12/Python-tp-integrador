# %%
import sys
from pathlib import Path
sys.path.append('../src')
import ej02_funciones
import csv

ruta = Path('..') / 'raw_datasets' / 'xeno-canto-bird-sounds-filtered' / 'Occurrence.txt'

ej02_funciones.imprimir_1ras_10filas(ruta)
print(f"-------------------"*20)
ej02_funciones.imprimir_columnas(ruta)
print(f"-------------------"*20)
ej02_funciones.retornar_indice_columna(ruta)
print(f"-------------------"*20)
print(ej02_funciones.cant_total_registros(ruta))
print(f"-------------------"*20)
print(ej02_funciones.columnas_vacias(ruta))
print(f"-------------------"*20)
porcentaje = ej02_funciones.porcentaje_columnas_nulas(ruta)
for keys, values in porcentaje.items():
    print(f"{keys} : {values} %")
print(f"-------------------"*20)
nombre = input("Escriba el nombre de una columna: ")
res = ej02_funciones.dado_nombre_columna(ruta,nombre)
if res != None:
    print(f"La cantidad de valores distintos de {nombre} es: {res}")
print(f"-------------------"*20)
nombre_columna = input("Escriba el nombre de una columna: ")
res_columna = ej02_funciones.frecuencia_columna(ruta,nombre_columna)
for keys, values in res_columna.items():
    print(f"{keys} : {values}")
# Out:
# {'id': '999540@XC', 'occurrenceID': 'https://data.biodiversitydata.nl/xeno-canto/observation/XC999540', 'catalogNumber': 'XC999540', 'basisOfRecord': 'HumanObservation', 'collectionCode': 'Wildlife sounds - Birds', 'dynamicProperties': '', 'otherCatalogNumbers': '', 'genus': 'Elaenia', 'specificEpithet': 'chilensis', 'infraspecificEpithet': '', 'scientificName': 'Elaenia chilensis', 'taxonRank': 'species', 'kingdom': 'Animalia', 'family': 'Tyrannidae', 'higherClassification': 'Animalia|PASSERIFORMES|Tyrannidae', 'nomenclaturalCode': 'ICZN', 'identificationRemarks': '', 'vernacularName': 'Chilean Elaenia', 'longitudeDecimal': '-60.6486', 'latitudeDecimal': '-32.8606', 'geodeticDatum': 'WGS84', 'country': 'Argentina', 'locality': 'Victoria, Entre Ríos', 'verbatimElevation': '10 m', 'recordedBy': 'Franco Vushurovich', 'eventDate': '2025-05-03', 'eventTime': '11:22', 'verbatimEventDate': '2025-05-03', 'fieldNotes': 'Vocalizando a baja altura en el denso albardón de Salix humbltiana y Tes
# ...
